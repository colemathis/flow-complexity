# %% [markdown]
# # load the data

# %%
ts <- read.csv("data/timeseries.csv")

# %% [markdown]
# # filter the data

# %%
ts <- ts[ts$time == 100, ]
ts <- ts[ts$sim_number %in% c(30, 60, 100), ]

# %% [markdown]
# # calculate assembly index of integers

# %%
ai <- read.csv("Assembly-10000.csv")

for (i in 1:nrow(ts)) {
  this_int <- ts$integer[i]
  this_ai <- ai$assemblyindex[ai$integer == this_int]
  if (length(this_ai) == 0) {
    this_ai <- 17
  }
  ts$assemblyindex[i] <- this_ai
}

# %% [markdown]
# # calculate the weighted average over each chemostat

# %%
library(dplyr)

ts <- ts %>%
  group_by(sim_number, chemostat_id) %>%
  summarize(
    mean_ai = sum(assemblyindex * frequency) / sum(frequency), # Weighted mean
    sd_ai = sqrt(sum(frequency * (assemblyindex - mean(assemblyindex))^2) / sum(frequency)), # Weighted SD
    .groups = "drop"
  )

# %% [markdown]
# # append the distance from source

# %%
dist <- read.csv("distance_from_source.csv")

for (i in 1:nrow(ts)) {
    this_sim_number <- ts$sim_number[i]
    this_chemostat_id <- ts$chemostat_id[i]
    this_dist <- dist$distance_from_source[dist$sim_number == this_sim_number & dist$chemostat_id == this_chemostat_id]
    ts$distance[i] <- this_dist
}
# Out:
# Warning message:
# “Unknown or uninitialised column: `distance`.”

# %% [markdown]
# # plot everything

# %%
library(ggplot2)
library(latex2exp)

p <- ggplot(ts, aes(x = distance, y = mean_ai, linetype = factor(sim_number))) +
  geom_point(alpha = 0.40, color = "black", show.legend = FALSE) +
  # geom_errorbar(aes(ymin = mean_ai - sd_ai, ymax = mean_ai + sd_ai), width = 0.1) + # Add error bars
  geom_smooth(data = ts %>% filter(sim_number == 30), method = "loess", span = 4.20, se = FALSE, color = "black", show.legend = FALSE) +  
  geom_smooth(data = ts %>% filter(sim_number == 60, distance < 6), method = "loess", span = 0.75, se = FALSE, color = "black", show.legend = FALSE) +  
  geom_smooth(data = ts %>% filter(sim_number == 100), method = "loess", span = 4.20, se = FALSE, color = "black", show.legend = FALSE) +  
  labs(
    x = "Distance",
    y = "Mean AI"
  ) +
  scale_linetype_manual(values = c("solid", "dotted", "dotdash")) + # Specify line styles
  annotate("rect", xmin = 4.5, xmax = 5.5, ymin = 3.5, ymax = 4.5, 
           color = "grey", fill = NA, linetype = "dashed") +
  annotate("text", x = 0.5, y = 0.3, label = TeX("$k_d = 10^{-4}$"), size = 3, color = "black") +
  annotate("text", x = 3.5, y = 2.5, label = TeX("$k_d = 10^{-2}$"), size = 3, color = "black") +
  annotate("text", x = 7, y = 4.5, label = TeX("$k_d = 10^{1}$"), size = 3, color = "black") +
  theme_minimal() + 
  theme(legend.position = "none")  # Hide legend

# print(p)

# ggsave(filename = "figs/test.pdf", plot = p, width = 80, height = 70, units = "mm")

# %% [markdown]
# # load and filter the data again

# %%
ts <- read.csv("data/timeseries.csv")

ts <- ts[ts$time == 100, ]
ts <- ts[ts$sim_number %in% c(30, 60, 100), ]

ai <- read.csv("Assembly-10000.csv")

for (i in 1:nrow(ts)) {
  this_int <- ts$integer[i]
  this_ai <- ai$assemblyindex[ai$integer == this_int]
  if (length(this_ai) == 0) {
    this_ai <- 17
  }
  ts$assemblyindex[i] <- this_ai
}

dist <- read.csv("distance_from_source.csv")

for (i in 1:nrow(ts)) {
    this_sim_number <- ts$sim_number[i]
    this_chemostat_id <- ts$chemostat_id[i]
    this_dist <- dist$distance_from_source[dist$sim_number == this_sim_number & dist$chemostat_id == this_chemostat_id]
    ts$distance[i] <- this_dist
}

# %% [markdown]
# # filter for chemostats sim_number = 100 and distance = 5

# %%
ts <- ts[ts$sim_number == 100, ]
ts <- ts[ts$distance == 5, ]

# %%
p2 <- ggplot(ts, aes(x = integer, y = frequency, linetype = factor(chemostat_id))) +
  # geom_point(alpha = 1.0) +
  # scale_x_log10() +
  scale_y_log10() +
  geom_density(aes(y = ..scaled..), adjust = 2, alpha = 1.0) +
  labs(
    x = "Integer",
    y = "Density",
    color = "chemostat_id"
  ) +
  theme_minimal() +
  theme(legend.position = "none",
  axis.text.x = element_blank(),
  axis.text.y = element_blank(),
  axis.title.x = element_text(size = 9),
  axis.title.y = element_text(size = 9)
  )

# print(p2)

# ggsave(filename = "figs/tmp.pdf", plot = p2, width = 80, height = 70, units = "mm")

# %% [markdown]
# # now create inset

# %%
library(grid)

# Convert the inset plot to a grob
inset_grob <- ggplotGrob(p2)

xmin = 4.50
xmax = 8.25
ymin = 0.75
ymax = 3.25

# Add the inset plot to the main plot using annotation_custom()
combined_plot <- p +
  annotation_custom(
    grob = rectGrob(
      gp = gpar(fill = "white", col = "black", lwd = 1) # Rectangle with white fill and black border
    ),
    xmin = xmin, xmax = xmax,
    ymin = ymin, ymax = ymax
  ) +
  annotation_custom(
    grob = inset_grob,
    xmin = xmin, xmax = xmax,
    ymin = ymin, ymax = ymax
  )

# Display the combined plot
print(combined_plot)

ggsave(filename = "figs/08C_distance-from-source_BEACON.pdf", plot = combined_plot, width = 80, height = 70, units = "mm")
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# `geom_smooth()` using formula = 'y ~ x'
# `geom_smooth()` using formula = 'y ~ x'
# Warning message in is.na(x):
# “is.na() applied to non-(list or vector) of type 'expression'”
# Warning message in is.na(x):
# “is.na() applied to non-(list or vector) of type 'expression'”
# Warning message in is.na(x):
# “is.na() applied to non-(list or vector) of type 'expression'”
# `geom_smooth()` using formula = 'y ~ x'
# `geom_smooth()` using formula = 'y ~ x'
# `geom_smooth()` using formula = 'y ~ x'
# Warning message in is.na(x):
# “is.na() applied to non-(list or vector) of type 'expression'”
# Warning message in is.na(x):
# “is.na() applied to non-(list or vector) of type 'expression'”
# Warning message in is.na(x):
# “is.na() applied to non-(list or vector) of type 'expression'”
# plot without title
